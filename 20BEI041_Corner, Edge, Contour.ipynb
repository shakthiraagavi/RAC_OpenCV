# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
chess = cv2.imread(r"C:\Users\DELL\Downloads\board.jfif")
chess = cv2.cvtColor(chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(chess)

# %%
gray_chess = cv2.cvtColor(chess,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_chess, cmap='gray')

# %%
gray = np.float32(gray_chess)
dst = cv2.cornerHarris(src = gray, blockSize = 2, ksize = 3, k = 0.04)

# %%
dst = cv2.dilate(dst, None)

# %%
chess[dst>0.01*dst.max()] = [255,0,0]

# %%
plt.imshow(chess)

# %%
img = cv2.imread(r"C:\Users\DELL\Downloads\tiger.jpg")

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img, threshold1=127,threshold2=127)

# %%
plt.imshow(edges)

# %%
edges = cv2.Canny(image=img, threshold1=0,threshold2=225)

# %%
plt.imshow(edges)

# %%
med_val = np.median(img)

# %%
med_val
# Out:
# 57.0

# %%
lower = int(max(0,0.07*med_val))
upper = int(min(255,1.3*med_val))

# %%
edges = cv2.Canny(image=img, threshold1=lower,threshold2=upper+200)
plt.imshow(edges)

# %%
upper
# Out:
# 74

# %%
blurred_img = cv2.blur(img, ksize = (7,7))

# %%
edges = cv2.Canny(image = blurred_img, threshold1 = lower, threshold2 = upper+40)
plt.imshow(edges)

# %%
image = cv2.imread(r"C:\Users\DELL\Downloads\Contour.jpg")

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
_, binary = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)
plt.imshow(binary, cmap="gray")
plt.show()

# %%
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

# %%
plt.imshow(image)
plt.show()
