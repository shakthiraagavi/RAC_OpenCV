# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tkinter import font

# %%
img = cv2.imread(r"C:\Users\DELL\Downloads\navyblue.jpg")

# %%
img.shape
# Out:
# (341, 512, 3)

# %%
plt.imshow(img)

# %%
cv2.rectangle(img,pt1=(384,0),pt2=(510,150),color=(255,255,255),thickness=10)
# Out:
# array([[[ 52,   5,   7],
#         [ 50,   6,   7],
#         [ 46,   6,   7],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 50,   6,   7],
#         [ 48,   6,   7],
#         [ 45,   7,   7],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 46,   8,   8],
#         [ 46,   8,   8],
#         [ 44,   8,   8],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 46,   8,   8],
#         [ 46,   8,   8],
#         [ 46,   8,   8],
#         ...,
#         [ 47,   7,   8],
#         [ 46,   8,   8],
#         [ 46,   8,   8]],
#
#        [[ 46,   8,   8],
#         [ 46,   8,   8],
#         [ 44,   8,   8],
#         ...,
#         [ 49,   7,   8],
#         [ 49,   7,   8],
#         [ 49,   7,   8]],
#
#        [[ 47,   9,   9],
#         [ 46,   8,   8],
#         [ 46,   8,   8],
# ...

# %%
plt.imshow(img)

# %%
cv2.circle(img,center=(200,200),radius=40,color=(0,255,0),thickness=7)
plt.imshow(img)

# %%
cv2.circle(img,center=(50,50),radius=40,color=(255,0,0),thickness=-1)
plt.imshow(img)

# %%
cv2.line(img,pt1=(500,0),pt2=(0,300),color=(123,123,123),thickness=10)
plt.imshow(img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, text = 'OpenCV', org = (10,500),fontFace=font, fontScale=4, color=(225,225,225), thickness=3, lineType=cv2.LINE_AA)
plt.imshow(img)

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int32)

# %%
plt.imshow(blank_img)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))

# %%
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]])

# %%
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]])

# %%
cv2.polylines(blank_img, [pts], isClosed=True, color=(225,0,0),thickness=5)
plt.imshow(blank_img)

# %%
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,255,0),-1)
cv2.namedWindow(winname='my_drawing')
cv2.setMouseCallback('my_drawing', draw_circle)

# %%
img1 = np.zeros((512,512,3),np.int8)
while True:
    cv2.imshow('my_drawing',img1)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()
