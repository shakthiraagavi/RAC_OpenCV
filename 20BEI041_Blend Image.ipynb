# %%
import cv2
import matplotlib.pyplot as plt

img1 = cv2.imread(r'C:\Users\DELL\Downloads\snow.jpg')
img2 = cv2.imread(r'C:\Users\DELL\Downloads\quote.PNG')
 
img1 = cv2.resize(img1, (400, 400))
img2 = cv2.resize(img2, (400, 400))
 
result = cv2.addWeighted(img1, 0.7, img2, 0.3, 0.0);

# %%
plt.imshow(result)
